# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import json
import requests
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt
from citipy import citipy
import random
from datetime import datetime
import seaborn as sns

# %% [markdown]
# ## Generate Cities List

# %%
cities = []

while len(cities)<600:
        lats = (random.choice(range(-90,90)))
        longs = (random.choice(range(-180,180)))
        city= citipy.nearest_city(lats,longs).city_name
        
        if city not in cities:
            cities.append(city)
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
from api_keys_weather import api_key
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
appid = api_key
settings = {"units": "imperial", "appid": api_key}
query_url = f"{url}appid={api_key}&units={units}&q="
response = requests.get(query_url + city).json()
response
# Out:
# {'coord': {'lon': -77.6328, 'lat': 49.7502},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 51.8,
#   'feels_like': 47.3,
#   'temp_min': 51.8,
#   'temp_max': 51.8,
#   'pressure': 1014,
#   'humidity': 13},
#  'visibility': 10000,
#  'wind': {'speed': 2.3, 'deg': 0},
#  'clouds': {'all': 1},
#  'dt': 1619559784,
#  'sys': {'type': 1,
#   'id': 866,
#   'country': 'CA',
#   'sunrise': 1619517244,
#   'sunset': 1619569314},
#  'timezone': -14400,
#  'id': 6067747,
#  'name': 'Matagami',
#  'cod': 200}

# %%
#city

# %%
#query_url

# %%
# set up lists to hold reponse info
lat = []
lon = []
temp = []
hum = []
cloud = []
wind = []
date = []
cit_num = 0
cit_name = []

# %%
# Loop through the list of cities and perform a request for data on each

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        date.append(response['dt'])
        cit_name.append(response['name'])
        cit_num = cit_num + 1
        
        print(f"Data found for city number: {cit_num}, city name: {response['name']}")
        
    except:
        print(f"City data for {city} not found. Move on to next.")
# Out:
# Data found for city number: 1, city name: Busselton
# Data found for city number: 2, city name: Qaanaaq
# Data found for city number: 3, city name: Bambous Virieux
# Data found for city number: 4, city name: Ribeira Grande
# Data found for city number: 5, city name: New Norfolk
# Data found for city number: 6, city name: Kapaa
# Data found for city number: 7, city name: Mayo
# City data for barentsburg not found. Move on to next.
# Data found for city number: 8, city name: Upernavik
# City data for sentyabrskiy not found. Move on to next.
# Data found for city number: 9, city name: Albany
# Data found for city number: 10, city name: Were Īlu
# Data found for city number: 11, city name: Broome
# Data found for city number: 12, city name: Brownsville
# Data found for city number: 13, city name: Saint-Philippe
# Data found for city number: 14, city name: Bredasdorp
# Data found for city number: 15, city name: Chui
# Data found for city number: 16, city name: Villa Carlos Paz
# Data found for city number: 17, city name: Kadyy
# Data found for city number: 18, city name: Tiksi
# Data found for city number: 19, city name: Rikitea
# Data found for city number: 20, city name: Port Elizabeth
# Data found for city number: 21, city name: Kailua
# Data found for city number: 22, city name: Tuktoyaktuk
# Data found for city number: 23, city name: Macia
# Data found for city number: 24, city name: Punta Arenas
# Data found for city number: 25, city name: Saint-Augustin
# Data found for city number: 223, city name: Batagay-Alyta
# Data found for city number: 224, city name: Makakilo City
# Data found for city number: 225, city name: Kiryat Gat
# Data found for city number: 226, city name: Grand-Santi
# Data found for city number: 227, city name: São João da Barra
# Data found for city number: 228, city name: Batemans Bay
# Data found for city number: 229, city name: Weligama
# Data found for city number: 230, city name: Kruisfontein
# Data found for city number: 231, city name: Carmarthen
# Data found for city number: 232, city name: Ternate
# Data found for city number: 233, city name: Punta Alta
# Data found for city number: 234, city name: Bela
# Data found for city number: 235, city name: Mehamn
# City data for banmo not found. Move on to next.
# Data found for city number: 236, city name: Sørland
# Data found for city number: 237, city name: Yellowknife
# Data found for city number: 238, city name: Rundu
# Data found for city number: 239, city name: Homer
# City data for illoqqortoormiut not found. Move on to next.
# Data found for city number: 240, city name: Guánica
# Data found for city number: 241, city name: Bonito
# Data found for city number: 242, city name: Numan
# Data found for city number: 243, city name: Paragominas
# Data found for city number: 244, city name: College
# Data found for city number: 245, city name: Udachny
# Data found for city number: 246, city name: Fortuna
# Data found for city number: 247, city name: Manta
# City data for mahadday weyne not found. Move on to next.
# Data found for city number: 248, city name: Palmer
# Data found for city number: 249, city name: Shingū
# Data found for city number: 250, city name: Niigata
# Data found for city number: 251, city name: Warkworth
# Data found for city number: 252, city name: At-Bashi
# Data found for city number: 253, city name: Batticaloa
# Data found for city number: 254, city name: Guerrero Negro
# City data for umzimvubu not found. Move on to next.
# Data found for city number: 255, city name: Cidreira
# Data found for city number: 256, city name: Salalah
# City data for amderma not found. Move on to next.
# Data found for city number: 257, city name: Oranjestad
# City data for dzhusaly not found. Move on to next.
# Data found for city number: 258, city name: Kutum
# Data found for city number: 259, city name: Pravda
# Data found for city number: 260, city name: Namie
# Data found for city number: 261, city name: Benghazi
# Data found for city number: 262, city name: Charlestown
# Data found for city number: 263, city name: Hambantota
# City data for macaboboni not found. Move on to next.
# Data found for city number: 264, city name: Linares
# Data found for city number: 265, city name: Ust-Nera
# Data found for city number: 266, city name: Los Llanos de Aridane
# Data found for city number: 267, city name: Kurumkan
# Data found for city number: 268, city name: Mandan
# City data for hihifo not found. Move on to next.
# Data found for city number: 269, city name: Port Hardy
# Data found for city number: 270, city name: Boa Vista
# Data found for city number: 271, city name: Huilong
# Data found for city number: 272, city name: Diego de Almagro
# Data found for city number: 273, city name: Nanortalik
# Data found for city number: 274, city name: Khāsh
# Data found for city number: 275, city name: Wukari
# Data found for city number: 276, city name: Bathsheba
# Data found for city number: 277, city name: Bethel
# Data found for city number: 278, city name: Neẖalim
# Data found for city number: 279, city name: Amurzet
# City data for karaul not found. Move on to next.
# Data found for city number: 280, city name: Minbu
# Data found for city number: 281, city name: Mount Gambier
# Data found for city number: 282, city name: Azare
# Data found for city number: 283, city name: São Filipe
# Data found for city number: 284, city name: Dicabisagan
# City data for carikar not found. Move on to next.
# Data found for city number: 285, city name: Lamar
# Data found for city number: 286, city name: Vredendal
# Data found for city number: 287, city name: Winslow
# Data found for city number: 288, city name: Jiblah
# City data for skagastrond not found. Move on to next.
# Data found for city number: 289, city name: Kargil
# Data found for city number: 290, city name: Waynesboro
# Data found for city number: 291, city name: Tonj
# Data found for city number: 292, city name: Las Vegas
# Data found for city number: 293, city name: Magnolia
# City data for malwan not found. Move on to next.
# Data found for city number: 294, city name: Clyde River
# Data found for city number: 295, city name: Alta Floresta
# Data found for city number: 296, city name: Kavieng
# Data found for city number: 297, city name: Knysna
# Data found for city number: 298, city name: Tonantins
# Data found for city number: 299, city name: Isangel
# Data found for city number: 300, city name: Jiazi
# Data found for city number: 301, city name: Camalú
# Data found for city number: 302, city name: Barcelona
# City data for yialos not found. Move on to next.
# Data found for city number: 303, city name: Iquique
# Data found for city number: 304, city name: Ouadda
# Data found for city number: 305, city name: Oga
# Data found for city number: 306, city name: Jackson
# Data found for city number: 307, city name: Shitanjing
# Data found for city number: 308, city name: Franklin
# City data for samusu not found. Move on to next.
# Data found for city number: 309, city name: Ukiah
# Data found for city number: 310, city name: Ābādān
# Data found for city number: 311, city name: Larvik
# Data found for city number: 312, city name: Yangi Marg`ilon
# Data found for city number: 313, city name: Abhā
# Data found for city number: 314, city name: Nkoteng
# City data for attawapiskat not found. Move on to next.
# Data found for city number: 315, city name: Sisophon
# Data found for city number: 316, city name: Salekhard
# Data found for city number: 317, city name: Biak
# Data found for city number: 318, city name: Hibbing
# Data found for city number: 319, city name: Bull Savanna
# Data found for city number: 320, city name: Fort William
# Data found for city number: 321, city name: Saldanha
# Data found for city number: 322, city name: Karratha
# Data found for city number: 323, city name: Anamur
# Data found for city number: 324, city name: Nampula
# Data found for city number: 325, city name: Sitka
# Data found for city number: 326, city name: Tignère
# Data found for city number: 327, city name: Mayumba
# Data found for city number: 328, city name: East Wenatchee
# Data found for city number: 329, city name: Saint-Pierre
# Data found for city number: 330, city name: Bubaque
# Data found for city number: 331, city name: Magadan
# Data found for city number: 332, city name: Raja
# Data found for city number: 333, city name: Marabu
# Data found for city number: 334, city name: Dunedin
# Data found for city number: 335, city name: North Bend
# Data found for city number: 336, city name: Kaitangata
# City data for viligili not found. Move on to next.
# Data found for city number: 337, city name: Paharpur
# Data found for city number: 338, city name: Ayan
# Data found for city number: 339, city name: Nivala
# Data found for city number: 340, city name: Bereda
# Data found for city number: 341, city name: Abbeville
# Data found for city number: 342, city name: Plérin
# City data for cam pha not found. Move on to next.
# Data found for city number: 343, city name: Puerto Escondido
# Data found for city number: 344, city name: São Gabriel da Cachoeira
# Data found for city number: 345, city name: Gorontalo
# Data found for city number: 346, city name: Svobody
# Data found for city number: 347, city name: Pangody
# Data found for city number: 348, city name: Vestmannaeyjar
# Data found for city number: 349, city name: Lorengau
# Data found for city number: 350, city name: Coahuayana Viejo
# Data found for city number: 351, city name: Marawi
# Data found for city number: 352, city name: Boende
# Data found for city number: 353, city name: Shimoda
# Data found for city number: 354, city name: Touros
# Data found for city number: 355, city name: Rognan
# Data found for city number: 356, city name: Tombouctou
# Data found for city number: 357, city name: Gurupá
# Data found for city number: 358, city name: Minas
# Data found for city number: 359, city name: Sokolo
# Data found for city number: 360, city name: Cayenne
# Data found for city number: 361, city name: Songling
# Data found for city number: 362, city name: Naryan-Mar
# Data found for city number: 363, city name: Tank
# Data found for city number: 364, city name: Kuala Lipis
# Data found for city number: 365, city name: Nur
# City data for temaraia not found. Move on to next.
# Data found for city number: 366, city name: Olafsvik
# City data for tsihombe not found. Move on to next.
# Data found for city number: 367, city name: Sur
# Data found for city number: 368, city name: Lufilufi
# Data found for city number: 369, city name: Kaeo
# Data found for city number: 370, city name: Bud
# Data found for city number: 371, city name: Yeppoon
# Data found for city number: 372, city name: Kenai
# Data found for city number: 373, city name: Turukhansk
# City data for toliary not found. Move on to next.
# Data found for city number: 374, city name: Baykit
# Data found for city number: 375, city name: Lompoc
# Data found for city number: 376, city name: Alekseyevka
# Data found for city number: 377, city name: Oistins
# Data found for city number: 378, city name: Tessalit
# Data found for city number: 379, city name: Ujhāni
# City data for maimon not found. Move on to next.
# Data found for city number: 380, city name: Lewistown
# Data found for city number: 381, city name: Huarmey
# Data found for city number: 382, city name: Pontes e Lacerda
# Data found for city number: 383, city name: Schenectady
# Data found for city number: 384, city name: Kushima
# Data found for city number: 385, city name: Isla Mujeres
# Data found for city number: 386, city name: Yurimaguas
# Data found for city number: 387, city name: Atar
# Data found for city number: 388, city name: Semey
# Data found for city number: 389, city name: Talnakh
# Data found for city number: 390, city name: Khovd
# Data found for city number: 391, city name: Jati
# Data found for city number: 392, city name: Bonavista
# Data found for city number: 393, city name: Port Lincoln
# Data found for city number: 394, city name: Dukat
# Data found for city number: 395, city name: Okhotsk
# Data found for city number: 396, city name: Santa Isabel
# Data found for city number: 397, city name: Cabra
# Data found for city number: 398, city name: Athabasca
# Data found for city number: 399, city name: Estevan
# Data found for city number: 400, city name: Libreville
# Data found for city number: 401, city name: Metro
# Data found for city number: 402, city name: Yinchuan
# City data for palabuhanratu not found. Move on to next.
# Data found for city number: 403, city name: Vidim
# Data found for city number: 404, city name: Brae
# Data found for city number: 405, city name: Butiá
# Data found for city number: 406, city name: Esso
# Data found for city number: 407, city name: Mahdalynivka
# City data for khagrachari not found. Move on to next.
# Data found for city number: 408, city name: Sterling
# Data found for city number: 409, city name: Powassan
# Data found for city number: 410, city name: Pailón
# City data for marcona not found. Move on to next.
# Data found for city number: 411, city name: Sawākin
# Data found for city number: 412, city name: Great Falls
# Data found for city number: 413, city name: Laguna
# Data found for city number: 414, city name: Ixtapa
# Data found for city number: 415, city name: Launceston
# Data found for city number: 416, city name: Eldorado
# Data found for city number: 417, city name: Port Blair
# Data found for city number: 418, city name: Provincia di Cremona
# Data found for city number: 419, city name: Rincon
# Data found for city number: 420, city name: Castle Douglas
# Data found for city number: 421, city name: Nadadores
# Data found for city number: 491, city name: Klæbu
# Data found for city number: 492, city name: Hobyo
# Data found for city number: 493, city name: Walvis Bay
# Data found for city number: 494, city name: Praia da Vitória
# Data found for city number: 495, city name: Merauke
# Data found for city number: 496, city name: Nuuk
# Data found for city number: 497, city name: Takoradze
# Data found for city number: 498, city name: Buraidah
# Data found for city number: 499, city name: Plettenberg Bay
# Data found for city number: 500, city name: Ponta do Sol
# Data found for city number: 501, city name: Sampit
# City data for alotau not found. Move on to next.
# Data found for city number: 502, city name: Miyako
# Data found for city number: 503, city name: Orbetello
# Data found for city number: 504, city name: Slave Lake
# Data found for city number: 505, city name: Talcahuano
# Data found for city number: 506, city name: Victor Harbor
# Data found for city number: 507, city name: Yefremov
# Data found for city number: 508, city name: Shakiso
# Data found for city number: 509, city name: Vao
# Data found for city number: 510, city name: Coldwater
# Data found for city number: 511, city name: Alyangula
# Data found for city number: 512, city name: Shepetivka
# Data found for city number: 513, city name: Kingaroy
# Data found for city number: 514, city name: Cache Creek
# Data found for city number: 515, city name: Jalingo
# City data for bolshegrivskoye not found. Move on to next.
# Data found for city number: 516, city name: Inta
# Data found for city number: 517, city name: Jaleshwar
# Data found for city number: 518, city name: Richards Bay
# Data found for city number: 519, city name: Itarema
# Data found for city number: 520, city name: Agüimes
# Data found for city number: 521, city name: Kalmunai
# Data found for city number: 522, city name: Mabaruma
# Data found for city number: 523, city name: Castrillón
# Data found for city number: 524, city name: Ust-Tsilma
# Data found for city number: 525, city name: Nushki
# Data found for city number: 526, city name: Evensk
# Data found for city number: 527, city name: Portland
# Data found for city number: 528, city name: Bandarbeyla
# Data found for city number: 529, city name: Archidona
# Data found for city number: 530, city name: Phang Nga
# Data found for city number: 531, city name: Cherepovets
# Data found for city number: 532, city name: Kiunga
# Data found for city number: 533, city name: Teya
# Data found for city number: 534, city name: Mahon
# Data found for city number: 535, city name: Río Gallegos
# Data found for city number: 536, city name: Thunder Bay
# Data found for city number: 537, city name: Vardø
# Data found for city number: 538, city name: Verāval
# Data found for city number: 539, city name: Dno
# Data found for city number: 540, city name: Wagar
# Data found for city number: 541, city name: Pingshan
# Data found for city number: 542, city name: Northam
# Data found for city number: 543, city name: Caravelas
# Data found for city number: 544, city name: Kroya
# Data found for city number: 545, city name: Ondjiva
# Data found for city number: 546, city name: Weiser
# Data found for city number: 547, city name: Matagami

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {"City": cit_name, "Latitude": lat, "Longitude": lon,
"Max Temp": temp, "Humidity": hum, "Cloudiness": cloud, "Wind Speed": wind, "Date": date}

weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#               City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0        Busselton  -33.6500   115.3333     54.00        97          40
# 1          Qaanaaq   77.4840   -69.3632     38.68        93         100
# 2  Bambous Virieux  -20.3428    57.7575     77.00        94          75
# 3   Ribeira Grande   38.5167   -28.7000     60.87        80          98
# 4      New Norfolk  -42.7826   147.0587     46.99        91          91
#
#    Wind Speed        Date
# 0        3.76  1619559785
# 1        4.47  1619559785
# 2       10.36  1619559785
# 3       14.34  1619559786
# 4        3.02  1619559786

# %%
weather_data.count()
# Out:
# City          547
# Latitude      547
# Longitude     547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Date          547
# dtype: int64

# %%
weather_data.to_csv("WeatherPy.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data.describe()
# Out:
#          Latitude   Longitude    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  547.000000  547.000000  547.000000  547.000000  547.000000  547.000000
# mean    20.196322   16.471182   60.911664   68.861060   51.071298    7.278903
# std     33.385527   91.052907   19.755019   23.855772   38.600903    4.806735
# min    -54.800000 -179.166700    4.660000    6.000000    0.000000    0.310000
# 25%     -6.868150  -63.617650   46.990000   54.500000    9.500000    3.510000
# 50%     24.951000   18.936700   64.000000   76.000000   52.000000    5.990000
# 75%     47.541750   99.759900   77.565000   88.000000   90.000000   10.360000
# max     78.218600  179.316700   97.700000  100.000000  100.000000   26.460000
#
#                Date
# count  5.470000e+02
# mean   1.619560e+09
# std    7.550736e+01
# min    1.619559e+09
# 25%    1.619560e+09
# 50%    1.619560e+09
# 75%    1.619560e+09
# max    1.619560e+09

# %%
#  Get the indices of cities that have humidity over 100%.
try:
    res = next(x for x, val in enumerate(hum) if val > 100)

    print("The index of element just greater than 100 : "+ str(res))

except:
    print("There are no cities with humidity over 100")
# Out:
# There are no cities with humidity over 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
## Convert to floats and store as x and y values
x_values = weather_data['Latitude'].astype('float')
y_values = weather_data['Max Temp'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, alpha=0.8, edgecolor="black", linewidths=1)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs. Max Temperature ({datetime.now().date()})')
plt.grid(True)
sns.set

# Print r square value
print(f"R squared: {rvalue**2}")

plt.savefig("LatVsTemp.png")

# Show plot
plt.show()
# Out:
# R squared: 0.26973979115888846

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
## Convert to floats and store as x and y values
x_values = weather_data['Latitude'].astype('float')
y_values = weather_data['Humidity'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, alpha=0.8, edgecolor="black", linewidths=1)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs. Humidity ({datetime.now().date()})')
plt.grid(True)
sns.set

# Print r square value
print(f"R squared: {rvalue**2}")

plt.savefig("LatVsHum.png")

# Show plot
plt.show()
# Out:
# R squared: 0.011680313900944927

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
## Convert to floats and store as x and y values
x_values = weather_data['Latitude'].astype('float')
y_values = weather_data['Cloudiness'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, alpha=0.8, edgecolor="black", linewidths=1)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-60,0),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs. Cloudiness ({datetime.now().date()})')
plt.grid(True)
sns.set

# Print r square value
print(f"R squared: {rvalue**2}")

plt.savefig("LatVsCloud.png")

# Show plot
plt.show()
# Out:
# R squared: 0.005813847305718423

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
## Convert to floats and store as x and y values
x_values = weather_data['Latitude'].astype('float')
y_values = weather_data['Wind Speed'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values, alpha=0.8, edgecolor="black", linewidths=1)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,25),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs. Wind Speed ({datetime.now().date()})')
plt.grid(True)
sns.set

# Print r square value
print(f"R squared: {rvalue**2}")

plt.savefig("LatVsWind.png")

# Show plot
plt.show()
# Out:
# R squared: 0.011781083559974129

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
